# %% [markdown]
# # Deep Learning Project Using ANN Model

# %%
# Part 1 - Data Preprocessing

# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Importing the dataset
dataset = pd.read_csv('Churn_Modelling.csv')
X = dataset.iloc[:, 3:13]
y = dataset.iloc[:, 13]

# %%
dataset.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
dataset.isnull().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
#Create dummy variables
geography=pd.get_dummies(X["Geography"],drop_first=True)
gender=pd.get_dummies(X['Gender'],drop_first=True)

# %%
## Concatenate the Data Frames
X=pd.concat([X,geography,gender],axis=1)

# %%
## Drop Unnecessary columns
X=X.drop(['Geography','Gender'],axis=1)

# %%
# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
# Part 2 - Now let's make the ANN!

# Importing the Keras libraries and packages
import tensorflow.keras as keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Dropout

# %%
# Initialising the ANN
classifier = Sequential()

# %%
# Adding the input layer and the first hidden layer
classifier.add(Dense(units = 10,kernel_initializer='he_uniform',activation='relu',input_dim = 11))

# %%
# Adding the second hidden layer
classifier.add(Dense(units = 10, kernel_initializer = 'he_uniform',activation='relu'))
# Adding the output layer
classifier.add(Dense(units = 1, kernel_initializer = 'glorot_uniform', activation = 'sigmoid'))

# %%
# Compiling the ANN
classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
# Fitting the ANN to the Training set
model_history=classifier.fit(X_train, y_train,validation_split=0.33, batch_size = 100,epochs = 100)
# Out:
# Epoch 1/100
# 54/54 [==============================] - 1s 4ms/step - loss: 0.9998 - accuracy: 0.2601 - val_loss: 0.7936 - val_accuracy: 0.3756
# Epoch 2/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.6975 - accuracy: 0.5316 - val_loss: 0.6273 - val_accuracy: 0.6622
# Epoch 3/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.5847 - accuracy: 0.7397 - val_loss: 0.5535 - val_accuracy: 0.7774
# Epoch 4/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.5300 - accuracy: 0.7934 - val_loss: 0.5131 - val_accuracy: 0.8005
# Epoch 5/100
# 54/54 [==============================] - 0s 1ms/step - loss: 0.4972 - accuracy: 0.8046 - val_loss: 0.4886 - val_accuracy: 0.8020
# Epoch 6/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.4756 - accuracy: 0.8084 - val_loss: 0.4714 - val_accuracy: 0.8035
# Epoch 7/100
# 54/54 [==============================] - 0s 1ms/step - loss: 0.4600 - accuracy: 0.8093 - val_loss: 0.4596 - val_accuracy: 0.8046
# Epoch 8/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.4483 - accuracy: 0.8117 - val_loss: 0.4503 - val_accuracy: 0.8095
# Epoch 9/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.4391 - accuracy: 0.8132 - val_loss: 0.4428 - val_accuracy: 0.8145
# Epoch 10/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.4316 - accuracy: 0.8145 - val_loss: 0.4367 - val_accuracy: 0.8152
# Epoch 11/100
# 54/54 [==============================] - 0s 1ms/step - loss: 0.4253 - accuracy: 0.8168 - val_loss: 0.4316 - val_accuracy: 0.8156
# Epoch 12/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.4196 - accuracy: 0.8214 - val_loss: 0.4272 - val_accuracy: 0.8156
# Epoch 13/100
# 54/54 [==============================] - 0s 1ms/step - loss: 0.4144 - accuracy: 0.8244 - val_loss: 0.4230 - val_accuracy: 0.8179
# Epoch 14/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.4094 - accuracy: 0.8274 - val_loss: 0.4193 - val_accuracy: 0.8220
# Epoch 15/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.4049 - accuracy: 0.8280 - val_loss: 0.4154 - val_accuracy: 0.8228
# Epoch 16/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.4000 - accuracy: 0.8326 - val_loss: 0.4116 - val_accuracy: 0.8239
# Epoch 17/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.3954 - accuracy: 0.8339 - val_loss: 0.4075 - val_accuracy: 0.8262
# Epoch 18/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.3906 - accuracy: 0.8367 - val_loss: 0.4038 - val_accuracy: 0.8270
# Epoch 19/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.3859 - accuracy: 0.8399 - val_loss: 0.3998 - val_accuracy: 0.8292
# Epoch 20/100
# 54/54 [==============================] - 0s 1ms/step - loss: 0.3808 - accuracy: 0.8414 - val_loss: 0.3961 - val_accuracy: 0.8326
# Epoch 21/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.3763 - accuracy: 0.8444 - val_loss: 0.3924 - val_accuracy: 0.8334
# Epoch 22/100
# 54/54 [==============================] - 0s 1ms/step - loss: 0.3722 - accuracy: 0.8447 - val_loss: 0.3897 - val_accuracy: 0.8342
# Epoch 23/100
# 54/54 [==============================] - 0s 1ms/step - loss: 0.3683 - accuracy: 0.8475 - val_loss: 0.3867 - val_accuracy: 0.8338
# Epoch 24/100
# 54/54 [==============================] - 0s 1ms/step - loss: 0.3646 - accuracy: 0.8472 - val_loss: 0.3843 - val_accuracy: 0.8326
# Epoch 25/100
# 54/54 [==============================] - 0s 1ms/step - loss: 0.3618 - accuracy: 0.8507 - val_loss: 0.3828 - val_accuracy: 0.8334
# Epoch 26/100
# 54/54 [==============================] - 0s 1ms/step - loss: 0.3589 - accuracy: 0.8511 - val_loss: 0.3807 - val_accuracy: 0.8330
# Epoch 27/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.3569 - accuracy: 0.8509 - val_loss: 0.3793 - val_accuracy: 0.8345
# Epoch 28/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.3552 - accuracy: 0.8531 - val_loss: 0.3775 - val_accuracy: 0.8387
# Epoch 29/100
# 54/54 [==============================] - 0s 1ms/step - loss: 0.3531 - accuracy: 0.8541 - val_loss: 0.3767 - val_accuracy: 0.8372
# Epoch 30/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.3512 - accuracy: 0.8550 - val_loss: 0.3757 - val_accuracy: 0.8368
# Epoch 31/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.3499 - accuracy: 0.8535 - val_loss: 0.3755 - val_accuracy: 0.8376
# Epoch 32/100
# 54/54 [==============================] - 0s 1ms/step - loss: 0.3487 - accuracy: 0.8559 - val_loss: 0.3751 - val_accuracy: 0.8387
# Epoch 33/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.3475 - accuracy: 0.8558 - val_loss: 0.3749 - val_accuracy: 0.8383
# Epoch 34/100
# 54/54 [==============================] - 0s 1ms/step - loss: 0.3462 - accuracy: 0.8548 - val_loss: 0.3738 - val_accuracy: 0.8410
# Epoch 35/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.3461 - accuracy: 0.8563 - val_loss: 0.3742 - val_accuracy: 0.8372
# Epoch 36/100
# 54/54 [==============================] - 0s 1ms/step - loss: 0.3449 - accuracy: 0.8567 - val_loss: 0.3740 - val_accuracy: 0.8379
# Epoch 37/100
# 54/54 [==============================] - 0s 1ms/step - loss: 0.3442 - accuracy: 0.8550 - val_loss: 0.3736 - val_accuracy: 0.8379
# Epoch 38/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.3428 - accuracy: 0.8559 - val_loss: 0.3731 - val_accuracy: 0.8391
# Epoch 39/100
# 54/54 [==============================] - 0s 1ms/step - loss: 0.3421 - accuracy: 0.8574 - val_loss: 0.3734 - val_accuracy: 0.8387
# Epoch 40/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.3417 - accuracy: 0.8565 - val_loss: 0.3731 - val_accuracy: 0.8391
# Epoch 41/100
# 54/54 [==============================] - 0s 1ms/step - loss: 0.3409 - accuracy: 0.8580 - val_loss: 0.3738 - val_accuracy: 0.8387
# Epoch 42/100
# 54/54 [==============================] - 0s 1ms/step - loss: 0.3409 - accuracy: 0.8578 - val_loss: 0.3734 - val_accuracy: 0.8398
# Epoch 43/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.3400 - accuracy: 0.8559 - val_loss: 0.3722 - val_accuracy: 0.8402
# Epoch 44/100
# 54/54 [==============================] - 0s 1ms/step - loss: 0.3391 - accuracy: 0.8571 - val_loss: 0.3718 - val_accuracy: 0.8406
# Epoch 45/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.3385 - accuracy: 0.8578 - val_loss: 0.3719 - val_accuracy: 0.8398
# Epoch 46/100
# 54/54 [==============================] - 0s 1ms/step - loss: 0.3384 - accuracy: 0.8584 - val_loss: 0.3726 - val_accuracy: 0.8406
# Epoch 47/100
# 54/54 [==============================] - 0s 1ms/step - loss: 0.3379 - accuracy: 0.8578 - val_loss: 0.3713 - val_accuracy: 0.8402
# Epoch 48/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.3374 - accuracy: 0.8586 - val_loss: 0.3717 - val_accuracy: 0.8425
# Epoch 49/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.3370 - accuracy: 0.8580 - val_loss: 0.3715 - val_accuracy: 0.8417
# Epoch 50/100
# 54/54 [==============================] - 0s 1ms/step - loss: 0.3367 - accuracy: 0.8593 - val_loss: 0.3704 - val_accuracy: 0.8413
# Epoch 51/100
# 54/54 [==============================] - 0s 1ms/step - loss: 0.3362 - accuracy: 0.8591 - val_loss: 0.3702 - val_accuracy: 0.8406
# Epoch 52/100
# 54/54 [==============================] - 0s 1ms/step - loss: 0.3365 - accuracy: 0.8582 - val_loss: 0.3703 - val_accuracy: 0.8413
# Epoch 53/100
# 54/54 [==============================] - 0s 1ms/step - loss: 0.3360 - accuracy: 0.8602 - val_loss: 0.3698 - val_accuracy: 0.8425
# Epoch 54/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.3355 - accuracy: 0.8593 - val_loss: 0.3698 - val_accuracy: 0.8421
# Epoch 55/100
# 54/54 [==============================] - 0s 1ms/step - loss: 0.3352 - accuracy: 0.8599 - val_loss: 0.3697 - val_accuracy: 0.8436
# Epoch 56/100
# 54/54 [==============================] - 0s 1ms/step - loss: 0.3349 - accuracy: 0.8593 - val_loss: 0.3695 - val_accuracy: 0.8421
# Epoch 57/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.3345 - accuracy: 0.8599 - val_loss: 0.3694 - val_accuracy: 0.8429
# Epoch 58/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.3344 - accuracy: 0.8578 - val_loss: 0.3696 - val_accuracy: 0.8417
# Epoch 59/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.3342 - accuracy: 0.8591 - val_loss: 0.3695 - val_accuracy: 0.8432
# Epoch 60/100
# 54/54 [==============================] - 0s 1ms/step - loss: 0.3337 - accuracy: 0.8602 - val_loss: 0.3687 - val_accuracy: 0.8417
# Epoch 61/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.3336 - accuracy: 0.8574 - val_loss: 0.3685 - val_accuracy: 0.8429
# Epoch 62/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.3331 - accuracy: 0.8608 - val_loss: 0.3687 - val_accuracy: 0.8451
# Epoch 63/100
# 54/54 [==============================] - 0s 1ms/step - loss: 0.3330 - accuracy: 0.8597 - val_loss: 0.3684 - val_accuracy: 0.8417
# Epoch 64/100
# 54/54 [==============================] - 0s 1ms/step - loss: 0.3325 - accuracy: 0.8604 - val_loss: 0.3675 - val_accuracy: 0.8425
# Epoch 65/100
# 54/54 [==============================] - 0s 1ms/step - loss: 0.3320 - accuracy: 0.8600 - val_loss: 0.3683 - val_accuracy: 0.8425
# Epoch 66/100
# 54/54 [==============================] - 0s 1ms/step - loss: 0.3320 - accuracy: 0.8599 - val_loss: 0.3677 - val_accuracy: 0.8440
# Epoch 67/100
# 54/54 [==============================] - 0s 1ms/step - loss: 0.3319 - accuracy: 0.8584 - val_loss: 0.3678 - val_accuracy: 0.8432
# Epoch 68/100
# 54/54 [==============================] - 0s 1ms/step - loss: 0.3314 - accuracy: 0.8599 - val_loss: 0.3674 - val_accuracy: 0.8451
# Epoch 69/100
# 54/54 [==============================] - 0s 1ms/step - loss: 0.3309 - accuracy: 0.8604 - val_loss: 0.3676 - val_accuracy: 0.8451
# Epoch 70/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.3306 - accuracy: 0.8612 - val_loss: 0.3680 - val_accuracy: 0.8451
# Epoch 71/100
# 54/54 [==============================] - 0s 1ms/step - loss: 0.3301 - accuracy: 0.8602 - val_loss: 0.3669 - val_accuracy: 0.8440
# Epoch 72/100
# 54/54 [==============================] - 0s 1ms/step - loss: 0.3301 - accuracy: 0.8615 - val_loss: 0.3666 - val_accuracy: 0.8436
# Epoch 73/100
# 54/54 [==============================] - 0s 1ms/step - loss: 0.3295 - accuracy: 0.8604 - val_loss: 0.3665 - val_accuracy: 0.8432
# Epoch 74/100
# 54/54 [==============================] - 0s 1ms/step - loss: 0.3296 - accuracy: 0.8632 - val_loss: 0.3677 - val_accuracy: 0.8459
# Epoch 75/100
# 54/54 [==============================] - 0s 1ms/step - loss: 0.3296 - accuracy: 0.8604 - val_loss: 0.3663 - val_accuracy: 0.8436
# Epoch 76/100
# 54/54 [==============================] - 0s 1ms/step - loss: 0.3289 - accuracy: 0.8612 - val_loss: 0.3674 - val_accuracy: 0.8459
# Epoch 77/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.3289 - accuracy: 0.8610 - val_loss: 0.3661 - val_accuracy: 0.8451
# Epoch 78/100
# 54/54 [==============================] - 0s 1ms/step - loss: 0.3282 - accuracy: 0.8630 - val_loss: 0.3658 - val_accuracy: 0.8459
# Epoch 79/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.3284 - accuracy: 0.8621 - val_loss: 0.3655 - val_accuracy: 0.8451
# Epoch 80/100
# 54/54 [==============================] - 0s 1ms/step - loss: 0.3277 - accuracy: 0.8643 - val_loss: 0.3657 - val_accuracy: 0.8466
# Epoch 81/100
# 54/54 [==============================] - 0s 1ms/step - loss: 0.3278 - accuracy: 0.8621 - val_loss: 0.3651 - val_accuracy: 0.8451
# Epoch 82/100
# 54/54 [==============================] - 0s 1ms/step - loss: 0.3271 - accuracy: 0.8632 - val_loss: 0.3653 - val_accuracy: 0.8470
# Epoch 83/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.3267 - accuracy: 0.8632 - val_loss: 0.3649 - val_accuracy: 0.8459
# Epoch 84/100
# 54/54 [==============================] - 0s 1ms/step - loss: 0.3267 - accuracy: 0.8649 - val_loss: 0.3654 - val_accuracy: 0.8482
# Epoch 85/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.3265 - accuracy: 0.8627 - val_loss: 0.3647 - val_accuracy: 0.8485
# Epoch 86/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.3261 - accuracy: 0.8630 - val_loss: 0.3645 - val_accuracy: 0.8455
# Epoch 87/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.3259 - accuracy: 0.8643 - val_loss: 0.3651 - val_accuracy: 0.8459
# Epoch 88/100
# 54/54 [==============================] - 0s 1ms/step - loss: 0.3256 - accuracy: 0.8636 - val_loss: 0.3650 - val_accuracy: 0.8474
# Epoch 89/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.3256 - accuracy: 0.8630 - val_loss: 0.3645 - val_accuracy: 0.8466
# Epoch 90/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.3252 - accuracy: 0.8640 - val_loss: 0.3638 - val_accuracy: 0.8444
# Epoch 91/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.3251 - accuracy: 0.8627 - val_loss: 0.3648 - val_accuracy: 0.8478
# Epoch 92/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.3248 - accuracy: 0.8628 - val_loss: 0.3644 - val_accuracy: 0.8489
# Epoch 93/100
# 54/54 [==============================] - 0s 1ms/step - loss: 0.3246 - accuracy: 0.8628 - val_loss: 0.3644 - val_accuracy: 0.8474
# Epoch 94/100
# 54/54 [==============================] - 0s 1ms/step - loss: 0.3247 - accuracy: 0.8640 - val_loss: 0.3647 - val_accuracy: 0.8459
# Epoch 95/100
# 54/54 [==============================] - 0s 1ms/step - loss: 0.3244 - accuracy: 0.8634 - val_loss: 0.3653 - val_accuracy: 0.8466
# Epoch 96/100
# 54/54 [==============================] - 0s 1ms/step - loss: 0.3245 - accuracy: 0.8643 - val_loss: 0.3644 - val_accuracy: 0.8470
# Epoch 97/100
# 54/54 [==============================] - 0s 1ms/step - loss: 0.3239 - accuracy: 0.8647 - val_loss: 0.3653 - val_accuracy: 0.8436
# Epoch 98/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.3242 - accuracy: 0.8634 - val_loss: 0.3645 - val_accuracy: 0.8463
# Epoch 99/100
# 54/54 [==============================] - 0s 1ms/step - loss: 0.3238 - accuracy: 0.8636 - val_loss: 0.3649 - val_accuracy: 0.8470
# Epoch 100/100
# 54/54 [==============================] - 0s 1ms/step - loss: 0.3236 - accuracy: 0.8634 - val_loss: 0.3639 - val_accuracy: 0.8489

# %%
 #Part 3 - Making the predictions and evaluating the model

# Predicting the Test set results
y_pred = classifier.predict(X_test)
y_pred = (y_pred > 0.5)
# Out:
# 63/63 [==============================] - 0s 721us/step

# %%
# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)

# Calculate the Accuracy
from sklearn.metrics import accuracy_score
score = accuracy_score(y_pred, y_test)

print("Accuracy: ", score)
# Out:
# Accuracy:  0.866
